# %% [markdown]
# # IEX Market Data
#
# This notebook explains how to obtain data from the [IEX Market Data](https://iextrading.com/developer/docs/#iex-market-data) endpoints. There are four such endpoints, accessible by top-level functions.
#
# * [TOPS](https://iextrading.com/developer/docs/#tops) - ``get_market_tops``
# * [Last](https://iextrading.com/developer/docs/#last) - ``get_market_last``
# * [DEEP](https://iextrading.com/developer/docs/#deep) - ``get_market_deep``
# * [Book](https://iextrading.com/developer/docs/#book52) - ``get_market_book``

# %%
from iexfinance import (get_market_tops, get_market_last, 
                        get_market_deep, get_market_book)

# %% [markdown]
# ### TOPS
#
# Per IEX:
#
# > TOPS provides IEX’s aggregated best quoted bid and offer position in near real time for all securities on IEX’s displayed limit order book. TOPS is ideal for developers needing both quote and trade data.
#
# We can first call ``get_market_tops`` with no parameters:

# %%
len(get_market_tops())
# Out:
# 8603

# %% [markdown]
# This is quite a long list, which is expected given that the function returns the current detailed quote for *all* IEX-listed symbols. We can limit our request to a symbol or list of symbols as well:

# %%
get_market_tops("AAPL")
# Out:
# [{'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 260.64,
#   'lastSaleSize': 55,
#   'lastSaleTime': 1522786443267,
#   'lastUpdated': 1522789200000,
#   'marketPercent': 0.01459,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'SPY',
#   'volume': 1749532},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 47.89,
#   'lastSaleSize': 1230,
#   'lastSaleTime': 1522785602006,
#   'lastUpdated': 1522788457099,
#   'marketPercent': 0.02434,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'EEM',
#   'volume': 1270192},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 33.465,
#   'lastSaleSize': 89,
#   'lastSaleTime': 1522785596100,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03906,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'CMCSA',
#   'volume': 1141242},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 29.595,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785598612,
#   'lastUpdated': 1522789001381,
#   'marketPercent': 0.01638,
#   'sector': 'banks',
#   'securityType': 'commonstock',
#   'symbol': 'BAC',
#   'volume': 1138882},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 9.54,
#   'lastSaleSize': 1800,
#   'lastSaleTime': 1522785599031,
#   'lastUpdated': 1522788772881,
#   'marketPercent': 0.02073,
#   'sector': 'semiconductorssemiconductor',
#   'securityType': 'commonstock',
#   'symbol': 'AMD',
#   'volume': 1136761},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 60.04,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599270,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.13713,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'COP',
#   'volume': 1117637},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 13.135,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785594475,
#   'lastUpdated': 1522789200000,
#   'marketPercent': 0.01735,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'GE',
#   'volume': 1031140},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 168.39,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599992,
#   'lastUpdated': 1522789200000,
#   'marketPercent': 0.03176,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'AAPL',
#   'volume': 958606},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 149.56,
#   'lastSaleSize': 34,
#   'lastSaleTime': 1522785591401,
#   'lastUpdated': 1522789044753,
#   'marketPercent': 0.03085,
#   'sector': 'n/a',
#   'securityType': 'n/a',
#   'symbol': 'SPOT',
#   'volume': 926317},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 39.08,
#   'lastSaleSize': 64,
#   'lastSaleTime': 1522785597583,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.23463,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'YNDX',
#   'volume': 921752},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 156.15,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598115,
#   'lastUpdated': 1522785787443,
#   'marketPercent': 0.02103,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'FB',
#   'volume': 884142},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 69.165,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595744,
#   'lastUpdated': 1522785604001,
#   'marketPercent': 0.02837,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'EFA',
#   'volume': 857854},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 14.075,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598501,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02346,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'SNAP',
#   'volume': 759716},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 89.79,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595506,
#   'lastUpdated': 1522788307583,
#   'marketPercent': 0.02025,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'MSFT',
#   'volume': 752829},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 3.455,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595092,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04766,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'ZNGA',
#   'volume': 724890},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 17.125,
#   'lastSaleSize': 900,
#   'lastSaleTime': 1522785599819,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05203,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'HPE',
#   'volume': 694293},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 9.805,
#   'lastSaleSize': 178,
#   'lastSaleTime': 1522785595426,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05911,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'RIG',
#   'volume': 682452},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 27.345,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598042,
#   'lastUpdated': 1522786294029,
#   'marketPercent': 0.00902,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'XLF',
#   'volume': 677576},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 41.37,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599278,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02411,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'CSCO',
#   'volume': 673278},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 56.65,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598909,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.10064,
#   'sector': 'healthcareequipmentservic',
#   'securityType': 'commonstock',
#   'symbol': 'CERN',
#   'volume': 658856},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 11.155,
#   'lastSaleSize': 137,
#   'lastSaleTime': 1522785594640,
#   'lastUpdated': 1522785807681,
#   'marketPercent': 0.01551,
#   'sector': 'automobilescomponents',
#   'securityType': 'commonstock',
#   'symbol': 'F',
#   'volume': 658630},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 2.165,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785586659,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02456,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'WFT',
#   'volume': 652854},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 35.695,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598474,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03312,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'PFE',
#   'volume': 646009},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 63.2,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598044,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.06157,
#   'sector': 'foodstaplesretailing',
#   'securityType': 'commonstock',
#   'symbol': 'WBA',
#   'volume': 645854},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 6.165,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785592126,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03948,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'SIRI',
#   'volume': 574105},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 17.385,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597181,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04542,
#   'sector': 'materials',
#   'securityType': 'commonstock',
#   'symbol': 'FCX',
#   'volume': 555408},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 267.75,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785868837,
#   'lastUpdated': 1522785868837,
#   'marketPercent': 0.02869,
#   'sector': 'automobilescomponents',
#   'securityType': 'commonstock',
#   'symbol': 'TSLA',
#   'volume': 540417},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 16.505,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595836,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0446,
#   'sector': 'telecommunicationservices',
#   'securityType': 'commonstock',
#   'symbol': 'CTL',
#   'volume': 538759},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 3.05,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785582144,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05045,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'RIGL',
#   'volume': 536646},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 174.575,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597511,
#   'lastUpdated': 1522787787610,
#   'marketPercent': 0.02676,
#   'sector': 'softwareservices',
#   'securityType': 'adr',
#   'symbol': 'BABA',
#   'volume': 533537},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 35.675,
#   'lastSaleSize': 211,
#   'lastSaleTime': 1522785591084,
#   'lastUpdated': 1522789200000,
#   'marketPercent': 0.02868,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'JNK',
#   'volume': 523578},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 51.565,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595366,
#   'lastUpdated': 1522789122049,
#   'marketPercent': 0.0099,
#   'sector': 'semiconductorssemiconductor',
#   'securityType': 'commonstock',
#   'symbol': 'MU',
#   'volume': 518523},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 27.545,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785598143,
#   'lastUpdated': 1522789076273,
#   'marketPercent': 0.01982,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'TWTR',
#   'volume': 515478},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 62.255,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595046,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.11934,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'EQR',
#   'volume': 513951},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 157.26,
#   'lastSaleSize': 300,
#   'lastSaleTime': 1522785600024,
#   'lastUpdated': 1522789047541,
#   'marketPercent': 0.00802,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'QQQ',
#   'volume': 513298},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 22.355,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598213,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.09768,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'ARNC',
#   'volume': 511563},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 18.69,
#   'lastSaleSize': 300,
#   'lastSaleTime': 1522785595377,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.06495,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'WU',
#   'volume': 494825},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 15.015,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785596388,
#   'lastUpdated': 1522786217685,
#   'marketPercent': 0.03192,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'KMI',
#   'volume': 487457},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 86.825,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598564,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05715,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'CELG',
#   'volume': 476174},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 49.785,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785596064,
#   'lastUpdated': 1522785862725,
#   'marketPercent': 0.01214,
#   'sector': 'semiconductorssemiconductor',
#   'securityType': 'commonstock',
#   'symbol': 'INTC',
#   'volume': 472473},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 21.915,
#   'lastSaleSize': 1794,
#   'lastSaleTime': 1522785599358,
#   'lastUpdated': 1522785726342,
#   'marketPercent': 0.01451,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'GDX',
#   'volume': 466885},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 90.65,
#   'lastSaleSize': 87,
#   'lastSaleTime': 1522785595105,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04491,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'ABBV',
#   'volume': 464505},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 6.065,
#   'lastSaleSize': 120,
#   'lastSaleTime': 1522785595561,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01857,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'MDR',
#   'volume': 455590},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 109.375,
#   'lastSaleSize': 13,
#   'lastSaleTime': 1522785580676,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03228,
#   'sector': 'banks',
#   'securityType': 'commonstock',
#   'symbol': 'JPM',
#   'volume': 453253},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 44.915,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785596717,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02834,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'ORCL',
#   'volume': 445323},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 62.79,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598401,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.07067,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'BMY',
#   'volume': 428485},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 35.36,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785599828,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0197,
#   'sector': 'telecommunicationservices',
#   'securityType': 'commonstock',
#   'symbol': 'T',
#   'volume': 425108},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 10.7,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599270,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02926,
#   'sector': 'consumerservices',
#   'securityType': 'commonstock',
#   'symbol': 'CZR',
#   'volume': 419748},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 150.22,
#   'lastSaleSize': 150,
#   'lastSaleTime': 1522787467820,
#   'lastUpdated': 1522789187363,
#   'marketPercent': 0.01323,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'IWM',
#   'volume': 406594},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 53.55,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785590031,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.18817,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'Z',
#   'volume': 405649},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 75.03,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599006,
#   'lastUpdated': 1522787524094,
#   'marketPercent': 0.02584,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'XOM',
#   'volume': 398642},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 13.35,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785588932,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04639,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'SWCH',
#   'volume': 378234},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 16.415,
#   'lastSaleSize': 358,
#   'lastSaleTime': 1522785587933,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.06444,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'FLEX',
#   'volume': 377255},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 12.785,
#   'lastSaleSize': 840,
#   'lastSaleTime': 1522785596436,
#   'lastUpdated': 1522788484834,
#   'marketPercent': 0.02809,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'IAU',
#   'volume': 375969},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 4.255,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785580403,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.07609,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'GRPN',
#   'volume': 371105},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 85.44,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599006,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05003,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'LOW',
#   'volume': 367480},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 99.4,
#   'lastSaleSize': 2,
#   'lastSaleTime': 1522785597632,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04346,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'DIS',
#   'volume': 367335},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 31.765,
#   'lastSaleSize': 400,
#   'lastSaleTime': 1522785586545,
#   'lastUpdated': 1522785600180,
#   'marketPercent': 0.06835,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'EWG',
#   'volume': 365580},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 5.425,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785537133,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03082,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'adr',
#   'symbol': 'NOK',
#   'volume': 364124},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 7.9,
#   'lastSaleSize': 388,
#   'lastSaleTime': 1522785597588,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04328,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'OAS',
#   'volume': 357586},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 8.255,
#   'lastSaleSize': 201,
#   'lastSaleTime': 1522785580473,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03336,
#   'sector': 'banks',
#   'securityType': 'adr',
#   'symbol': 'IBN',
#   'volume': 355499},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 19.99,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522788772049,
#   'lastUpdated': 1522789140101,
#   'marketPercent': 0.00832,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'UVXY',
#   'volume': 354254},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 62.595,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598240,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04547,
#   'sector': 'foodstaplesretailing',
#   'securityType': 'commonstock',
#   'symbol': 'CVS',
#   'volume': 353325},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 3.955,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785598010,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03243,
#   'sector': 'materials',
#   'securityType': 'commonstock',
#   'symbol': 'KGC',
#   'volume': 349343},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 46.93,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785599511,
#   'lastUpdated': 1522785623518,
#   'marketPercent': 0.01369,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'FXI',
#   'volume': 348715},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 2.915,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785579798,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01428,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'CHK',
#   'volume': 343832},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 36.955,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597715,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02178,
#   'sector': 'automobilescomponents',
#   'securityType': 'commonstock',
#   'symbol': 'GM',
#   'volume': 343225},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 5.595,
#   'lastSaleSize': 199,
#   'lastSaleTime': 1522785595031,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03886,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'CLNS',
#   'volume': 342099},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 68.505,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597198,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01805,
#   'sector': 'banks',
#   'securityType': 'commonstock',
#   'symbol': 'C',
#   'volume': 339373},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 4.635,
#   'lastSaleSize': 159,
#   'lastSaleTime': 1522785593933,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02387,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'P',
#   'volume': 338934},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 65.33,
#   'lastSaleSize': 600,
#   'lastSaleTime': 1522785599009,
#   'lastUpdated': 1522785601500,
#   'marketPercent': 0.02335,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'IEFA',
#   'volume': 336006},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 18.5,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785573259,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.13174,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'ATUS',
#   'volume': 333459},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 63.32,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595008,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02788,
#   'sector': 'materials',
#   'securityType': 'commonstock',
#   'symbol': 'DWDP',
#   'volume': 327973},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 4.225,
#   'lastSaleSize': 76,
#   'lastSaleTime': 1522785585489,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02353,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'SWN',
#   'volume': 326474},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 85.2,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785591057,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02511,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'HYG',
#   'volume': 326057},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 66.705,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598224,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03664,
#   'sector': 'consumerdurablesapparel',
#   'securityType': 'commonstock',
#   'symbol': 'NKE',
#   'volume': 320186},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 74.59,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595866,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03611,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'PYPL',
#   'volume': 320139},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 102.11,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599042,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04692,
#   'sector': 'semiconductorssemiconductor',
#   'securityType': 'commonstock',
#   'symbol': 'TXN',
#   'volume': 318700},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 3.185,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785556546,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0179,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'JCP',
#   'volume': 312839},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 4.965,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785589830,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02742,
#   'sector': 'telecommunicationservices',
#   'securityType': 'commonstock',
#   'symbol': 'S',
#   'volume': 308312},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 7.385,
#   'lastSaleSize': 900,
#   'lastSaleTime': 1522785599974,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04138,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'DDR',
#   'volume': 304604},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 51.16,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598429,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03904,
#   'sector': 'diversifiedfinancials',
#   'securityType': 'commonstock',
#   'symbol': 'SCHW',
#   'volume': 303787},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 13.655,
#   'lastSaleSize': 35,
#   'lastSaleTime': 1522785590693,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04731,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'WPX',
#   'volume': 297776},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 19.44,
#   'lastSaleSize': 400,
#   'lastSaleTime': 1522785595168,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0323,
#   'sector': 'banks',
#   'securityType': 'commonstock',
#   'symbol': 'KEY',
#   'volume': 292083},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 43.94,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595168,
#   'lastUpdated': 1522785602501,
#   'marketPercent': 0.02401,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'VEA',
#   'volume': 292054},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 57.915,
#   'lastSaleSize': 400,
#   'lastSaleTime': 1522785598939,
#   'lastUpdated': 1522785713001,
#   'marketPercent': 0.01571,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'IEMG',
#   'volume': 291474},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 9.385,
#   'lastSaleSize': 400,
#   'lastSaleTime': 1522785599430,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0223,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'AMLP',
#   'volume': 289317},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 46.725,
#   'lastSaleSize': 208,
#   'lastSaleTime': 1522785593904,
#   'lastUpdated': 1522785630509,
#   'marketPercent': 0.01856,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'VWO',
#   'volume': 289029},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 1.265,
#   'lastSaleSize': 2400,
#   'lastSaleTime': 1522785440804,
#   'lastUpdated': 1522786571228,
#   'marketPercent': 0.01945,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'EBIO',
#   'volume': 287576},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 22.945,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597610,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05126,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'HCP',
#   'volume': 284785},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 44.24,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597134,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.06447,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'RSPP',
#   'volume': 282919},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 16.01,
#   'lastSaleSize': 10,
#   'lastSaleTime': 1522785588418,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0353,
#   'sector': 'n/a',
#   'securityType': 'n/a',
#   'symbol': 'IQ',
#   'volume': 282019},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 11.515,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785596330,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03202,
#   'sector': 'utilities',
#   'securityType': 'commonstock',
#   'symbol': 'AES',
#   'volume': 279953},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 0.0435,
#   'lastSaleSize': 1188,
#   'lastSaleTime': 1522785571541,
#   'lastUpdated': 1522785599730,
#   'marketPercent': 0.00133,
#   'sector': 'healthcareequipmentservic',
#   'securityType': 'commonstock',
#   'symbol': 'NVCN',
#   'volume': 279058},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 65.47,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598209,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03887,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'ATVI',
#   'volume': 279012},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 64.48,
#   'lastSaleSize': 400,
#   'lastSaleTime': 1522785594067,
#   'lastUpdated': 1522787580702,
#   'marketPercent': 0.01547,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'XLK',
#   'volume': 278591},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 78.47,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595752,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02472,
#   'sector': 'householdpersonalproducts',
#   'securityType': 'commonstock',
#   'symbol': 'PG',
#   'volume': 277893},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 36.155,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785589176,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02674,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'FOXA',
#   'volume': 277492},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 20.415,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785592998,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03225,
#   'sector': 'semiconductorssemiconductor',
#   'securityType': 'commonstock',
#   'symbol': 'MRVL',
#   'volume': 276561},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 54.8,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598003,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03469,
#   'sector': 'semiconductorssemiconductor',
#   'securityType': 'commonstock',
#   'symbol': 'QCOM',
#   'volume': 274763},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 12.765,
#   'lastSaleSize': 600,
#   'lastSaleTime': 1522785595520,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01808,
#   'sector': 'materials',
#   'securityType': 'adr',
#   'symbol': 'VALE',
#   'volume': 274323},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 39.88,
#   'lastSaleSize': 1700,
#   'lastSaleTime': 1522785598069,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05599,
#   'sector': 'foodbeveragetobacco',
#   'securityType': 'commonstock',
#   'symbol': 'BUFF',
#   'volume': 273220},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 43.395,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597922,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01764,
#   'sector': 'foodbeveragetobacco',
#   'securityType': 'commonstock',
#   'symbol': 'KO',
#   'volume': 270081},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 46.82,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598011,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03616,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'HAL',
#   'volume': 269866},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 21.325,
#   'lastSaleSize': 110,
#   'lastSaleTime': 1522785598844,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03321,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'HPQ',
#   'volume': 269513},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 53.98,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598660,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0245,
#   'sector': 'semiconductorssemiconductor',
#   'securityType': 'commonstock',
#   'symbol': 'AMAT',
#   'volume': 268960},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 59.01,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785596515,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04391,
#   'sector': 'healthcareequipmentservic',
#   'securityType': 'commonstock',
#   'symbol': 'ABT',
#   'volume': 268147},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 31.1,
#   'lastSaleSize': 136,
#   'lastSaleTime': 1522785596076,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.09737,
#   'sector': 'commercialprofessionalserv',
#   'securityType': 'commonstock',
#   'symbol': 'NLSN',
#   'volume': 266526},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 1.64,
#   'lastSaleSize': 300,
#   'lastSaleTime': 1522785595802,
#   'lastUpdated': 1522787733895,
#   'marketPercent': 0.02118,
#   'sector': 'foodstaplesretailing',
#   'securityType': 'commonstock',
#   'symbol': 'RAD',
#   'volume': 265810},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 52.09,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598011,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01592,
#   'sector': 'banks',
#   'securityType': 'commonstock',
#   'symbol': 'WFC',
#   'volume': 264706},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 5.135,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785592416,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04851,
#   'sector': 'materials',
#   'securityType': 'commonstock',
#   'symbol': 'IAG',
#   'volume': 260523},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 119.22,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599039,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03648,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'V',
#   'volume': 258250},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 283.76,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595856,
#   'lastUpdated': 1522787400001,
#   'marketPercent': 0.02023,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'NFLX',
#   'volume': 256083},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 35.005,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598773,
#   'lastUpdated': 1522785810756,
#   'marketPercent': 0.0212,
#   'sector': 'materials',
#   'securityType': 'commonstock',
#   'symbol': 'X',
#   'volume': 254075},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 30.485,
#   'lastSaleSize': 116,
#   'lastSaleTime': 1522785593409,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05612,
#   'sector': 'utilities',
#   'securityType': 'commonstock',
#   'symbol': 'NRG',
#   'volume': 252513},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 40.76,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785596342,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.06971,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'DK',
#   'volume': 249248},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 86.8,
#   'lastSaleSize': 65,
#   'lastSaleTime': 1522785599020,
#   'lastUpdated': 1522787849323,
#   'marketPercent': 0.02532,
#   'sector': 'foodstaplesretailing',
#   'securityType': 'commonstock',
#   'symbol': 'WMT',
#   'volume': 244139},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 53.73,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595472,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0438,
#   'sector': 'insurance',
#   'securityType': 'commonstock',
#   'symbol': 'AIG',
#   'volume': 244107},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 41.245,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595395,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01355,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'CSRA',
#   'volume': 243166},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 82.33,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785596389,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.06104,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'TJX',
#   'volume': 242021},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 66.665,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785596301,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03267,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'OXY',
#   'volume': 240067},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 12.82,
#   'lastSaleSize': 400,
#   'lastSaleTime': 1522785597585,
#   'lastUpdated': 1522788301501,
#   'marketPercent': 0.02604,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'USO',
#   'volume': 238795},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 14.165,
#   'lastSaleSize': 300,
#   'lastSaleTime': 1522785598427,
#   'lastUpdated': 1522787345289,
#   'marketPercent': 0.03007,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'CBI',
#   'volume': 235063},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 28.985,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595107,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02893,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'M',
#   'volume': 234812},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 77.87,
#   'lastSaleSize': 7,
#   'lastSaleTime': 1522785599404,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05217,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'ETN',
#   'volume': 233542},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 6.935,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597070,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02342,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'VER',
#   'volume': 230993},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 128.38,
#   'lastSaleSize': 89,
#   'lastSaleTime': 1522785595628,
#   'lastUpdated': 1522787154719,
#   'marketPercent': 0.02885,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'JNJ',
#   'volume': 230775},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 27.355,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598193,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.06303,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'EWC',
#   'volume': 227622},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 7.855,
#   'lastSaleSize': 188,
#   'lastSaleTime': 1522785595045,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04234,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'SRC',
#   'volume': 225568},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 7.185,
#   'lastSaleSize': 300,
#   'lastSaleTime': 1522785589664,
#   'lastUpdated': 1522785823750,
#   'marketPercent': 0.01159,
#   'sector': 'foodbeveragetobacco',
#   'securityType': 'adr',
#   'symbol': 'ABEV',
#   'volume': 221735},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 25.67,
#   'lastSaleSize': 300,
#   'lastSaleTime': 1522785599245,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04714,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'SYMC',
#   'volume': 221498},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 114.9,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785594944,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03495,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'CVX',
#   'volume': 220800},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 62.675,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597806,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02541,
#   'sector': 'foodbeveragetobacco',
#   'securityType': 'commonstock',
#   'symbol': 'MO',
#   'volume': 220784},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 31.37,
#   'lastSaleSize': 4,
#   'lastSaleTime': 1522785595537,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03146,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'DVN',
#   'volume': 220776},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 20.355,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785594504,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03529,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'GGP',
#   'volume': 219457},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 34.44,
#   'lastSaleSize': 80,
#   'lastSaleTime': 1522785595106,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04706,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'JCI',
#   'volume': 217615},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 24.45,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595093,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02355,
#   'sector': 'energy',
#   'securityType': 'commonstock',
#   'symbol': 'WMB',
#   'volume': 215891},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 10.71,
#   'lastSaleSize': 500,
#   'lastSaleTime': 1522785599482,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02126,
#   'sector': 'banks',
#   'securityType': 'adr',
#   'symbol': 'BBD',
#   'volume': 215640},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 49.915,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785592502,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04249,
#   'sector': 'healthcareequipmentservic',
#   'securityType': 'commonstock',
#   'symbol': 'XRAY',
#   'volume': 215108},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 73.75,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598814,
#   'lastUpdated': 1522785999834,
#   'marketPercent': 0.03633,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'GILD',
#   'volume': 215055},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 29.43,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599255,
#   'lastUpdated': 1522787577765,
#   'marketPercent': 0.0313,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'VIAB',
#   'volume': 212868},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 10.345,
#   'lastSaleSize': 300,
#   'lastSaleTime': 1522785585033,
#   'lastUpdated': 1522788772228,
#   'marketPercent': 0.00323,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'TVIX',
#   'volume': 211948},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 18.405,
#   'lastSaleSize': 79,
#   'lastSaleTime': 1522785595404,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02545,
#   'sector': 'banks',
#   'securityType': 'commonstock',
#   'symbol': 'RF',
#   'volume': 211446},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 27.23,
#   'lastSaleSize': 7590,
#   'lastSaleTime': 1522785599677,
#   'lastUpdated': 1522785601740,
#   'marketPercent': 0.04312,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'SJNK',
#   'volume': 210812},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 116.5,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785590915,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04042,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'CRM',
#   'volume': 209547},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 50.315,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598183,
#   'lastUpdated': 1522789200000,
#   'marketPercent': 0.01509,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'XLU',
#   'volume': 208076},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 20.175,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785599743,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04591,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'DISCK',
#   'volume': 207606},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 23.3,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595137,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.08572,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'NYT',
#   'volume': 205749},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 78.35,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597425,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04764,
#   'sector': 'healthcareequipmentservic',
#   'securityType': 'commonstock',
#   'symbol': 'MDT',
#   'volume': 205300},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 95.19,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595851,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03859,
#   'sector': 'media',
#   'securityType': 'commonstock',
#   'symbol': 'TWX',
#   'volume': 204759},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 40.05,
#   'lastSaleSize': 89,
#   'lastSaleTime': 1522785588018,
#   'lastUpdated': 1522785600078,
#   'marketPercent': 0.0497,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'FEZ',
#   'volume': 204226},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 2.685,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785592299,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.06082,
#   'sector': 'telecommunicationservices',
#   'securityType': 'adr',
#   'symbol': 'VEON',
#   'volume': 201736},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 53.18,
#   'lastSaleSize': 20,
#   'lastSaleTime': 1522785595506,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01965,
#   'sector': 'diversifiedfinancials',
#   'securityType': 'commonstock',
#   'symbol': 'MS',
#   'volume': 200797},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 1391.11,
#   'lastSaleSize': 3,
#   'lastSaleTime': 1522785597579,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01965,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'AMZN',
#   'volume': 200607},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 31.185,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595056,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05626,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'GPS',
#   'volume': 200358},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 225.33,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598400,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01185,
# ...
#   'lastSaleTime': 1522785594327,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01644,
#   'sector': 'householdpersonalproducts',
#   'securityType': 'commonstock',
#   'symbol': 'KMB',
#   'volume': 39848},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 58.56,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785537300,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01279,
#   'sector': 'foodbeveragetobacco',
#   'securityType': 'adr',
#   'symbol': 'BTI',
#   'volume': 39784},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 25.895,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598202,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01932,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'DRE',
#   'volume': 39757},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 7.68,
#   'lastSaleSize': 10,
#   'lastSaleTime': 1522785595444,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05294,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'DERM',
#   'volume': 39632},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 25.325,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597656,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01838,
#   'sector': 'consumerservices',
#   'securityType': 'commonstock',
#   'symbol': 'HRB',
#   'volume': 39596},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 91.25,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599725,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01689,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'WDC',
#   'volume': 39460},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 32.01,
#   'lastSaleSize': 65,
#   'lastSaleTime': 1522785595945,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04872,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'PTLA',
#   'volume': 39399},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 334.93,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595668,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03034,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'LMT',
#   'volume': 39339},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 84.89,
#   'lastSaleSize': 56,
#   'lastSaleTime': 1522785583087,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02202,
#   'sector': 'commercialprofessionalserv',
#   'securityType': 'commonstock',
#   'symbol': 'WM',
#   'volume': 39239},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 9.05,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785587572,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02159,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'CHS',
#   'volume': 39218},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 20.615,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785599953,
#   'lastUpdated': 1522785910085,
#   'marketPercent': 0.01415,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'BBBY',
#   'volume': 39184},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 38.62,
#   'lastSaleSize': 4,
#   'lastSaleTime': 1522785595339,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.09576,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'LEXEA',
#   'volume': 39140},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 30.315,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785596455,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01796,
#   'sector': 'materials',
#   'securityType': 'commonstock',
#   'symbol': 'AXTA',
#   'volume': 39061},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 38.72,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595484,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02799,
#   'sector': 'semiconductorssemiconductor',
#   'securityType': 'commonstock',
#   'symbol': 'CRUS',
#   'volume': 39053},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 38.69,
#   'lastSaleSize': 149,
#   'lastSaleTime': 1522785595365,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02398,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'ITB',
#   'volume': 39053},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 106.91,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785592237,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02022,
#   'sector': 'retailing',
#   'securityType': 'commonstock',
#   'symbol': 'EXPE',
#   'volume': 39041},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 109.65,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785590206,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04984,
#   'sector': 'materials',
#   'securityType': 'commonstock',
#   'symbol': 'WLK',
#   'volume': 39039},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 30.145,
#   'lastSaleSize': 23,
#   'lastSaleTime': 1522785595794,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04671,
#   'sector': 'diversifiedfinancials',
#   'securityType': 'mlp',
#   'symbol': 'APO',
#   'volume': 39038},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 13.465,
#   'lastSaleSize': 103,
#   'lastSaleTime': 1522785598089,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01556,
#   'sector': 'banks',
#   'securityType': 'commonstock',
#   'symbol': 'ISBC',
#   'volume': 38994},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 19.42,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785592942,
#   'lastUpdated': 1522785744476,
#   'marketPercent': 0.01695,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'EMLC',
#   'volume': 38865},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 9.495,
#   'lastSaleSize': 84,
#   'lastSaleTime': 1522785588294,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01762,
#   'sector': 'materials',
#   'securityType': 'adr',
#   'symbol': 'AU',
#   'volume': 38847},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 13.02,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522784692201,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02375,
#   'sector': 'softwareservices',
#   'securityType': 'adr',
#   'symbol': 'CMCM',
#   'volume': 38771},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 15.865,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785525077,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01922,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'UNIT',
#   'volume': 38708},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 39.66,
#   'lastSaleSize': 88,
#   'lastSaleTime': 1522785597553,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02935,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'LPT',
#   'volume': 38669},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 28.83,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785594434,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0715,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'XNCR',
#   'volume': 38634},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 29.415,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598764,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01949,
#   'sector': 'media',
#   'securityType': 'misc',
#   'symbol': 'FWONK',
#   'volume': 38630},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 116.33,
#   'lastSaleSize': 6,
#   'lastSaleTime': 1522785582285,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.09389,
#   'sector': 'commercialprofessionalserv',
#   'securityType': 'commonstock',
#   'symbol': 'DNB',
#   'volume': 38528},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 81.89,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785592812,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0359,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'INCY',
#   'volume': 38526},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 32.79,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595854,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03444,
#   'sector': 'energy',
#   'securityType': 'mlp',
#   'symbol': 'MPLX',
#   'volume': 38519},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 9.55,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522779675352,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03092,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'ICLN',
#   'volume': 38500},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 42.62,
#   'lastSaleSize': 29,
#   'lastSaleTime': 1522785595197,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02268,
#   'sector': 'automobilescomponents',
#   'securityType': 'commonstock',
#   'symbol': 'HOG',
#   'volume': 38455},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 1.815,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785559778,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01039,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'SGYP',
#   'volume': 38443},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 65.21,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785592806,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05519,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'AGCO',
#   'volume': 38434},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 65.08,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785475136,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.158,
#   'sector': 'consumerservices',
#   'securityType': 'mlp',
#   'symbol': 'FUN',
#   'volume': 38390},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 4.71,
#   'lastSaleSize': 17,
#   'lastSaleTime': 1522785577118,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03929,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'adr',
#   'symbol': 'AUO',
#   'volume': 38298},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 10.485,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785580060,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01735,
#   'sector': 'realestate',
#   'securityType': 'reit',
#   'symbol': 'DRH',
#   'volume': 38288},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 10.33,
#   'lastSaleSize': 99,
#   'lastSaleTime': 1522785585344,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01989,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'EXTR',
#   'volume': 38266},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 35.26,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785585582,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05347,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'FM',
#   'volume': 38250},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 33.925,
#   'lastSaleSize': 200,
#   'lastSaleTime': 1522785577319,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02001,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'XME',
#   'volume': 38249},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 37.28,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785570477,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01354,
#   'sector': 'softwareservices',
#   'securityType': 'adr',
#   'symbol': 'MOMO',
#   'volume': 38201},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 1.15,
#   'lastSaleSize': 500,
#   'lastSaleTime': 1522785542575,
#   'lastUpdated': 1522785599114,
#   'marketPercent': 0.02104,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'PTN',
#   'volume': 38200},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 10.215,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785598659,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.0307,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'KTOS',
#   'volume': 38135},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 14,
#   'lastSaleSize': 5,
#   'lastSaleTime': 1522785593577,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.04057,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'ABEO',
#   'volume': 38048},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 91.83,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597544,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02183,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'CTXS',
#   'volume': 38027},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 61.03,
#   'lastSaleSize': 5,
#   'lastSaleTime': 1522785595874,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01935,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'PAYX',
#   'volume': 38013},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 65.36,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595419,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.03757,
#   'sector': 'softwareservices',
#   'securityType': 'commonstock',
#   'symbol': 'LDOS',
#   'volume': 37980},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 13.96,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785595253,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.01999,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'HZNP',
#   'volume': 37974},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 11.385,
#   'lastSaleSize': 81,
#   'lastSaleTime': 1522785426991,
#   'lastUpdated': 1522789200000,
#   'marketPercent': 0.00252,
#   'sector': 'n/a',
#   'securityType': 'etp',
#   'symbol': 'SVXY',
#   'volume': 37912},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 169.48,
#   'lastSaleSize': 100,
#   'lastSaleTime': 1522785597391,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02834,
#   'sector': 'capitalgoods',
#   'securityType': 'commonstock',
#   'symbol': 'URI',
#   'volume': 37899},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 26.325,
#   'lastSaleSize': 281,
#   'lastSaleTime': 1522785582150,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.05629,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'NTCT',
#   'volume': 37872},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 84.815,
#   'lastSaleSize': 96,
#   'lastSaleTime': 1522785597362,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.02739,
#   'sector': 'technologyhardwareequipmen',
#   'securityType': 'commonstock',
#   'symbol': 'APH',
#   'volume': 37625},
#  {'askPrice': 0,
#   'askSize': 0,
#   'bidPrice': 0,
#   'bidSize': 0,
#   'lastSalePrice': 112.92,
#   'lastSaleSize': 29,
#   'lastSaleTime': 1522785582033,
#   'lastUpdated': 1522785600001,
#   'marketPercent': 0.07573,
#   'sector': 'pharmaceuticalsbiotechnology',
#   'securityType': 'commonstock',
#   'symbol': 'ICLR',
#   'volume': 37607},
#  ...]

# %% [markdown]
# Pandas DataFrame output formatting is also supported by passing 'pandas' as the ``output_format`` parameter:

# %%
get_market_tops(["AAPL", "MSFT"], output_format='pandas')
# Out:
#       askPrice  askSize  bidPrice  bidSize  lastSalePrice  lastSaleSize  \
# 0            0        0         0        0        260.640            55
# 1            0        0         0        0         47.890          1230
# 2            0        0         0        0         33.465            89
# 3            0        0         0        0         29.595           200
# 4            0        0         0        0          9.540          1800
# 5            0        0         0        0         60.040           100
# 6            0        0         0        0         13.135           100
# 7            0        0         0        0        168.390           100
# 8            0        0         0        0        149.560            34
# 9            0        0         0        0         39.080            64
# 10           0        0         0        0        156.150           100
# 11           0        0         0        0         69.165           100
# 12           0        0         0        0         14.075           100
# 13           0        0         0        0         89.790           100
# 14           0        0         0        0          3.455           100
# 15           0        0         0        0         17.125           900
# 16           0        0         0        0          9.805           178
# 17           0        0         0        0         27.345           100
# 18           0        0         0        0         41.370           100
# 19           0        0         0        0         56.650           100
# 20           0        0         0        0         11.155           137
# 21           0        0         0        0          2.165           100
# 22           0        0         0        0         35.695           100
# 23           0        0         0        0         63.200           100
# 24           0        0         0        0          6.165           200
# 25           0        0         0        0         17.385           100
# 26           0        0         0        0        267.750           100
# 27           0        0         0        0         16.505           100
# 28           0        0         0        0          3.050           100
# 29           0        0         0        0        174.575           100
# ...        ...      ...       ...      ...            ...           ...
# 8573         0        0         0        0          0.000             0
# 8574         0        0         0        0          0.000             0
# 8575         0        0         0        0          0.000             0
# 8576         0        0         0        0          0.000             0
# 8577         0        0         0        0          0.000             0
# 8578         0        0         0        0          0.000             0
# 8579         0        0         0        0          0.000             0
# 8580         0        0         0        0          0.000             0
# 8581         0        0         0        0          0.000             0
# 8582         0        0         0        0          0.000             0
# 8583         0        0         0        0          0.000             0
# 8584         0        0         0        0          0.000             0
# 8585         0        0         0        0          0.000             0
# 8586         0        0         0        0         10.000          2000
# 8587         0        0         0        0          0.000             0
# 8588         0        0         0        0          1.000          2000
# 8589         0        0         0        0          0.000             0
# 8590         0        0         0        0          0.000             0
# 8591         0        0         0        0          0.000             0
# 8592         0        0         0        0          0.000             0
# 8593         0        0         0        0          0.000             0
# 8594         0        0         0        0          0.000             0
# 8595         0        0         0        0          0.000             0
# 8596         0        0         0        0          0.000             0
# 8597         0        0         0        0          0.000             0
# 8598         0        0         0        0         10.020           100
# 8599         0        0         0        0          0.000             0
# 8600         0        0         0        0        100.000          2000
# 8601         0        0         0        0          0.000             0
# 8602         0        0         0        0          0.000             0
#
#        lastSaleTime    lastUpdated  marketPercent  \
# 0     1522786443267  1522789200000        0.01459
# 1     1522785602006  1522788457099        0.02434
# 2     1522785596100  1522785600001        0.03906
# 3     1522785598612  1522789001381        0.01638
# 4     1522785599031  1522788772881        0.02073
# 5     1522785599270  1522785600001        0.13713
# 6     1522785594475  1522789200000        0.01735
# 7     1522785599992  1522789200000        0.03176
# 8     1522785591401  1522789044753        0.03085
# 9     1522785597583  1522785600001        0.23463
# 10    1522785598115  1522785787443        0.02103
# 11    1522785595744  1522785604001        0.02837
# 12    1522785598501  1522785600001        0.02346
# 13    1522785595506  1522788307583        0.02025
# 14    1522785595092  1522785600001        0.04766
# 15    1522785599819  1522785600001        0.05203
# 16    1522785595426  1522785600001        0.05911
# 17    1522785598042  1522786294029        0.00902
# 18    1522785599278  1522785600001        0.02411
# 19    1522785598909  1522785600001        0.10064
# 20    1522785594640  1522785807681        0.01551
# 21    1522785586659  1522785600001        0.02456
# 22    1522785598474  1522785600001        0.03312
# 23    1522785598044  1522785600001        0.06157
# 24    1522785592126  1522785600001        0.03948
# 25    1522785597181  1522785600001        0.04542
# 26    1522785868837  1522785868837        0.02869
# 27    1522785595836  1522785600001        0.04460
# 28    1522785582144  1522785600001        0.05045
# 29    1522785597511  1522787787610        0.02676
# ...             ...            ...            ...
# 8573              0             -1        0.00000
# 8574              0  1522785600001        0.00000
# 8575              0             -1        0.00000
# 8576              0             -1        0.00000
# 8577              0             -1        0.00000
# 8578              0             -1        0.00000
# 8579              0             -1        0.00000
# 8580              0             -1        0.00000
# 8581              0  1522785600001        0.00000
# 8582              0             -1        0.00000
# 8583              0  1522778312183        0.00000
# 8584              0             -1        0.00000
# 8585              0             -1        0.00000
# 8586  1522785600001             -1        0.00000
# 8587              0  1522763273235        0.00000
# 8588  1522785600001             -1        0.00000
# 8589              0  1522785600001        0.00000
# 8590              0             -1        0.00000
# 8591              0             -1        0.00000
# 8592              0  1522785599740        0.00000
# 8593              0  1522785600001        0.00000
# 8594              0             -1        0.00000
# 8595              0             -1        0.00000
# 8596              0             -1        0.00000
# 8597              0             -1        0.00000
# 8598  1522785012084  1522785571903        0.00000
# 8599              0             -1        0.00000
# 8600  1522785600001             -1        0.00000
# 8601              0             -1        0.00000
# 8602              0  1522788772227        0.02274
#
#                             sector   securityType symbol     volume
# 0                              n/a            etp    SPY    1749532
# 1                              n/a            etp    EEM    1270192
# 2                            media    commonstock  CMCSA    1141242
# 3                            banks    commonstock    BAC    1138882
# 4      semiconductorssemiconductor    commonstock    AMD    1136761
# 5                           energy    commonstock    COP    1117637
# 6                     capitalgoods    commonstock     GE    1031140
# 7       technologyhardwareequipmen    commonstock   AAPL     958606
# 8                              n/a            n/a   SPOT     926317
# 9                 softwareservices    commonstock   YNDX     921752
# 10                softwareservices    commonstock     FB     884142
# 11                             n/a            etp    EFA     857854
# 12                softwareservices    commonstock   SNAP     759716
# 13                softwareservices    commonstock   MSFT     752829
# 14                softwareservices    commonstock   ZNGA     724890
# 15      technologyhardwareequipmen    commonstock    HPE     694293
# 16                          energy    commonstock    RIG     682452
# 17                             n/a            etp    XLF     677576
# 18      technologyhardwareequipmen    commonstock   CSCO     673278
# 19       healthcareequipmentservic    commonstock   CERN     658856
# 20           automobilescomponents    commonstock      F     658630
# 21                          energy    commonstock    WFT     652854
# 22    pharmaceuticalsbiotechnology    commonstock    PFE     646009
# 23            foodstaplesretailing    commonstock    WBA     645854
# 24                           media    commonstock   SIRI     574105
# 25                       materials    commonstock    FCX     555408
# 26           automobilescomponents    commonstock   TSLA     540417
# 27       telecommunicationservices    commonstock    CTL     538759
# 28    pharmaceuticalsbiotechnology    commonstock   RIGL     536646
# 29                softwareservices            adr   BABA     533537
# ...                            ...            ...    ...        ...
# 8573                transportation    commonstock   YRIV          0
# 8574                        energy    commonstock   YUMA          0
# 8575                           n/a            etp    YXI          0
# 8576         diversifiedfinancials    commonstock   ZAIS          0
# 8577                           n/a           misc  ZAZZT          0
# 8578                           n/a           misc   ZB-A          0
# 8579                           n/a           misc   ZB-G          0
# 8580                           n/a           misc   ZB-H          0
# 8581                           n/a            etp   ZBIO          0
# 8582                           n/a           misc    ZBK          0
# 8583                           n/a           misc   ZBZX          0
# 8584                           n/a           misc  ZBZZT          0
# 8585                           n/a           misc  ZCZZT          0
# 8586                           n/a    commonstock  ZEXIT          0
# 8587                           n/a  closedendfund     ZF          0
# 8588                           n/a    commonstock  ZIEXT          0
# 8589                           n/a        warrant  ZIONW          0
# 8590                           n/a        warrant  ZIONZ          0
# 8591                           n/a           misc  ZJZZT          0
# 8592                           n/a            etp   ZMLP          0
# 8593                transportation            adr    ZNH          0
# 8594                           n/a        warrant  ZNWAA          0
# 8595                           n/a           misc  ZTEST          0
# 8596                           n/a           misc    ZVV          0
# 8597                           n/a           misc   ZVVV          0
# 8598                           n/a           misc  ZVZZT          0
# 8599                           n/a           misc  ZWZZT          0
# 8600                           n/a    commonstock  ZXIET          0
# 8601                           n/a           misc  ZXZZT          0
# 8602                           n/a            n/a   IEXG  325130014
#
# [8603 rows x 13 columns]

# %% [markdown]
# Per IEX:
#
# > Last provides trade data for executions on IEX. It is a near real time, intraday API that provides IEX last sale price, size and time. Last is ideal for developers that need a lightweight stock quote.
#
# Last acts similarly to TOPS. It supports JSON and Pandas DataFrame outputformatting. When passed no parameters, it returns trade data for all-listed IEX symbols. We can shorten this list by limiting our request to a symbol or list of symbols

# %%
get_market_last("AAPL", output_format='pandas')
# Out:
#         price  size symbol           time
# 0     260.640    55    SPY  1522786443267
# 1      47.890  1230    EEM  1522785602006
# 2      33.465    89  CMCSA  1522785596100
# 3      29.595   200    BAC  1522785598612
# 4       9.540  1800    AMD  1522785599031
# 5      60.040   100    COP  1522785599270
# 6      13.135   100     GE  1522785594475
# 7     168.390   100   AAPL  1522785599992
# 8     149.560    34   SPOT  1522785591401
# 9      39.080    64   YNDX  1522785597583
# 10    156.150   100     FB  1522785598115
# 11     69.165   100    EFA  1522785595744
# 12     14.075   100   SNAP  1522785598501
# 13     89.790   100   MSFT  1522785595506
# 14      3.455   100   ZNGA  1522785595092
# 15     17.125   900    HPE  1522785599819
# 16      9.805   178    RIG  1522785595426
# 17     27.345   100    XLF  1522785598042
# 18     41.370   100   CSCO  1522785599278
# 19     56.650   100   CERN  1522785598909
# 20     11.155   137      F  1522785594640
# 21      2.165   100    WFT  1522785586659
# 22     35.695   100    PFE  1522785598474
# 23     63.200   100    WBA  1522785598044
# 24      6.165   200   SIRI  1522785592126
# 25     17.385   100    FCX  1522785597181
# 26    267.750   100   TSLA  1522785868837
# 27     16.505   100    CTL  1522785595836
# 28      3.050   100   RIGL  1522785582144
# 29    174.575   100   BABA  1522785597511
# ...       ...   ...    ...            ...
# 8573    0.000     0   YRIV              0
# 8574    0.000     0   YUMA              0
# 8575    0.000     0    YXI              0
# 8576    0.000     0   ZAIS              0
# 8577    0.000     0  ZAZZT              0
# 8578    0.000     0   ZB-A              0
# 8579    0.000     0   ZB-G              0
# 8580    0.000     0   ZB-H              0
# 8581    0.000     0   ZBIO              0
# 8582    0.000     0    ZBK              0
# 8583    0.000     0   ZBZX              0
# 8584    0.000     0  ZBZZT              0
# 8585    0.000     0  ZCZZT              0
# 8586   10.000  2000  ZEXIT  1522785600001
# 8587    0.000     0     ZF              0
# 8588    1.000  2000  ZIEXT  1522785600001
# 8589    0.000     0  ZIONW              0
# 8590    0.000     0  ZIONZ              0
# 8591    0.000     0  ZJZZT              0
# 8592    0.000     0   ZMLP              0
# 8593    0.000     0    ZNH              0
# 8594    0.000     0  ZNWAA              0
# 8595    0.000     0  ZTEST              0
# 8596    0.000     0    ZVV              0
# 8597    0.000     0   ZVVV              0
# 8598   10.020   100  ZVZZT  1522785012084
# 8599    0.000     0  ZWZZT              0
# 8600  100.000  2000  ZXIET  1522785600001
# 8601    0.000     0  ZXZZT              0
# 8602    0.000     0   IEXG              0
#
# [8603 rows x 4 columns]

# %% [markdown]
# ### DEEP
#
# Per IEX:
#
# > DEEP is used to receive real-time depth of book quotations direct from IEX. The depth of book quotations received via DEEP provide an aggregated size of resting displayed orders at a price and side, and do not indicate the size or number of individual orders at any price level. Non-displayed orders and non-displayed portions of reserve orders are not represented in DEEP.
# > DEEP also provides last trade price and size information. Trades resulting from either displayed or non-displayed orders matching on IEX will be reported. Routed executions will not be reported.
#
# Unlike TOPS and Last, DEEP requires a symbol or list of symbols be passed. It also does not allow Pandas DataFrame output formatting

# %%
get_market_deep("AAPL")
# Out:
# {'asks': [],
#  'auction': {},
#  'bids': [],
#  'lastSalePrice': 168.39,
#  'lastSaleSize': 100,
#  'lastSaleTime': 1522785599992,
#  'lastUpdated': 1522789200000,
#  'marketPercent': 0.03176,
#  'officialPrice': {},
#  'opHaltStatus': {'isHalted': False, 'timestamp': 1522754950845},
#  'securityEvent': {'securityEvent': 'MarketClose', 'timestamp': 1522785600001},
#  'ssrStatus': {'detail': ' ', 'isSSR': False, 'timestamp': 1522754950845},
#  'symbol': 'AAPL',
#  'systemEvent': {'systemEvent': 'E', 'timestamp': 1522789200000},
#  'tradeBreaks': [],
#  'trades': [{'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.38,
#    'size': 100,
#    'timestamp': 1522785599453,
#    'tradeId': 1212637926},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.39,
#    'size': 100,
#    'timestamp': 1522785599992,
#    'tradeId': 1212821442},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.48,
#    'size': 100,
#    'timestamp': 1522785598008,
#    'tradeId': 1212161424},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.48,
#    'size': 100,
#    'timestamp': 1522785598008,
#    'tradeId': 1212161454},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.4,
#    'size': 100,
#    'timestamp': 1522785598452,
#    'tradeId': 1212342403},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.43,
#    'size': 100,
#    'timestamp': 1522785598595,
#    'tradeId': 1212374803},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.44,
#    'size': 100,
#    'timestamp': 1522785598829,
#    'tradeId': 1212425815},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.42,
#    'size': 100,
#    'timestamp': 1522785598830,
#    'tradeId': 1212426088},
#   {'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.445,
#    'size': 100,
#    'timestamp': 1522785597279,
#    'tradeId': 1211939091},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.47,
#    'size': 100,
#    'timestamp': 1522785597402,
#    'tradeId': 1211976162},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.48,
#    'size': 100,
#    'timestamp': 1522785597646,
#    'tradeId': 1212069376},
#   {'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.49,
#    'size': 100,
#    'timestamp': 1522785595532,
#    'tradeId': 1211353680},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.41,
#    'size': 100,
#    'timestamp': 1522785594691,
#    'tradeId': 1210906505},
#   {'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.395,
#    'size': 100,
#    'timestamp': 1522785595023,
#    'tradeId': 1211010050},
#   {'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.47,
#    'size': 100,
#    'timestamp': 1522785595196,
#    'tradeId': 1211169127},
#   {'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.39,
#    'size': 100,
#    'timestamp': 1522785594012,
#    'tradeId': 1210657683},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.38,
#    'size': 100,
#    'timestamp': 1522785594013,
#    'tradeId': 1210659775},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.38,
#    'size': 100,
#    'timestamp': 1522785594102,
#    'tradeId': 1210728921},
#   {'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.38,
#    'size': 100,
#    'timestamp': 1522785594345,
#    'tradeId': 1210817360},
#   {'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'price': 168.38,
#    'size': 100,
#    'timestamp': 1522785591958,
#    'tradeId': 1210138921}],
#  'tradingStatus': {'reason': '    ',
#   'status': 'T',
#   'timestamp': 1522754950845},
#  'volume': 958606}

# %% [markdown]
# ### Book
#
# Per IEX:
#
# > Book shows IEX’s bids and asks for given symbols.
#
# To display the bid/asks for a given (required) symbol or list of symbols, use ``get_market_book``

# %%
get_market_book("AAPL")
# Out:
# {'AAPL': {'asks': [], 'bids': []}}

# %% [markdown]
# Pandas DataFrame output is not supported

# %% [markdown]
# # Stock module

# %%
from iexfinance import Stock

# %% [markdown]
# We'll first import the Stock module from iexfinance. This will provide us access to each of the [stocks](https://iextrading.com/developer/docs/#stocks) endpoint groups. The groups are as follows:
#
# * Book
# * Chart
# * Company
# * Company
# ...
# * Quote
# * Relevant
# * Splits
# * Time Series
#
# To access each of these endpoint groups, iexfinance provides the ``Stock`` object.
#
# ## Creating a Stock object

# %%
aapl = Stock("AAPL")

# %% [markdown]
# We'll first work with the single ticker symbol "AAPL" for Apple inc. It's easy to access any of the endpoint groups above through the *endpoint methods* such as ``get_book``, ``get_quote``, etc.

# %%
aapl.get_quote()
# Out:
# {'avgTotalVolume': 34740512,
#  'calculationPrice': 'tops',
#  'change': -0.09,
#  'changePercent': -0.00054,
#  'close': 166.68,
#  'closeTime': 1522699200202,
#  'companyName': 'Apple Inc.',
#  'delayedPrice': 166.66,
#  'delayedPriceTime': 1522777132811,
#  'high': 167.8,
#  'iexAskPrice': 170.64,
#  'iexAskSize': 100,
#  'iexBidPrice': 166.59,
#  'iexBidSize': 100,
#  'iexLastUpdated': 1522778028334,
#  'iexMarketPercent': 0.03191,
#  'iexRealtimePrice': 166.59,
#  'iexRealtimeSize': 100,
#  'iexVolume': 599405,
#  'latestPrice': 166.59,
#  'latestSource': 'IEX real time price',
#  'latestTime': '1:53:48 PM',
#  'latestUpdate': 1522778028334,
#  'latestVolume': 18784237,
#  'low': 164.88,
#  'marketCap': 845279825670,
#  'open': 167.58,
#  'openTime': 1522762200485,
#  'peRatio': 17.12,
#  'previousClose': 166.68,
#  'primaryExchange': 'Nasdaq Global Select',
#  'sector': 'Technology',
#  'symbol': 'AAPL',
#  'week52High': 183.5,
#  'week52Low': 140.06,
#  'ytdChange': -0.028447690464879643}

# %% [markdown]
# By default, we see that the output format mirrors that of the IEX documentation, here returning a dictionary of the quote endpoints. Another way to achieve this output is to use the ``get_endpoints`` method.

# %%
aapl.get_endpoints('quote')
# Out:
# {'quote': {'avgTotalVolume': 34740512,
#   'calculationPrice': 'tops',
#   'change': -0.09,
#   'changePercent': -0.00054,
#   'close': 166.68,
#   'closeTime': 1522699200202,
#   'companyName': 'Apple Inc.',
#   'delayedPrice': 166.66,
#   'delayedPriceTime': 1522777132811,
#   'high': 167.8,
#   'iexAskPrice': 170.64,
#   'iexAskSize': 100,
#   'iexBidPrice': 166.59,
#   'iexBidSize': 100,
#   'iexLastUpdated': 1522778028334,
#   'iexMarketPercent': 0.03191,
#   'iexRealtimePrice': 166.59,
#   'iexRealtimeSize': 100,
#   'iexVolume': 599405,
#   'latestPrice': 166.59,
#   'latestSource': 'IEX real time price',
#   'latestTime': '1:53:48 PM',
#   'latestUpdate': 1522778028334,
#   'latestVolume': 18784237,
#   'low': 164.88,
#   'marketCap': 845279825670,
#   'open': 167.58,
#   'openTime': 1522762200485,
#   'peRatio': 17.12,
#   'previousClose': 166.68,
#   'primaryExchange': 'Nasdaq Global Select',
#   'sector': 'Technology',
#   'symbol': 'AAPL',
#   'week52High': 183.5,
#   'week52Low': 140.06,
#   'ytdChange': -0.028447690464879643}}

# %% [markdown]
# The ``get_endpoints`` method also allows the retrieval of multiple (up to 10) endpoints at once

# %%
aapl.get_endpoints(['quote', 'book', 'company', 'volume-by-venue']).keys()
# Out:
# dict_keys(['quote', 'book', 'company', 'volume-by-venue'])

# %% [markdown]
# ## Multiple Symbols
#
# Requests for multiple tickers (up to 100) at once are permissible. Simply pass a list of ticker symbols (as strings) when creating a Stock object.

# %%
batch = Stock(["AAPL", "MSFT", "TSLA"])
batch.get_price()
# Out:
# {'AAPL': 166.59, 'MSFT': 88.965, 'TSLA': 270.43}

# %% [markdown]
# By default, the endpoint methods will return a symbol-indexed dictionary of the endpoint requested. ``get_endpoints`` will do the same. **Note:** it is recommended that users limit the number of large requests using multiple tickers with the ``get_endpoints`` method.

# %% [markdown]
# ## Pandas DataFrame formatting
#
# Pandas DataFrame output formatting is supported in iexfinance through all endpoint methods. When creating the ``Stock`` object, simply pass a keyword argument ``output_format`` as follows:

# %%
tsla = Stock("TSLA", output_format='pandas')
tsla.get_quote()
# Out:
#                                   TSLA
# avgTotalVolume                 7140603
# calculationPrice                  tops
# change                           17.95
# changePercent                  0.07109
# close                           252.48
# closeTime                1522699200072
# companyName                 Tesla Inc.
# delayedPrice                    266.67
# delayedPriceTime         1522777135577
# high                            269.82
# iexAskPrice                     276.46
# iexAskSize                         100
# iexBidPrice                     263.03
# iexBidSize                         100
# iexLastUpdated           1522778012645
# iexMarketPercent               0.02571
# iexRealtimePrice                270.43
# iexRealtimeSize                    100
# iexVolume                       335330
# latestPrice                     270.43
# latestSource       IEX real time price
# latestTime                  1:53:32 PM
# latestUpdate             1522778012645
# latestVolume                  13042785
# low                             254.49
# marketCap                  45681019645
# open                               269
# openTime                 1522762200869
# peRatio                         -23.64
# previousClose                   252.48
# primaryExchange   Nasdaq Global Select
# sector               Consumer Cyclical
# symbol                            TSLA
# week52High                      389.61
# week52Low                       244.59
# ytdChange                    -0.212305

# %% [markdown]
# By default, the ``output_format`` parameter is set to 'json' to mirror the return of the provider, but it here has been changed to 'pandas'. This type of output formatting is available for multiple symbols as well, with a column provided for each ticker requested.

# %%
air = Stock(["AAL", "LUV", "DAL"], output_format='pandas')
air.get_quote()
# Out:
#                                            AAL                      DAL  \
# avgTotalVolume                         4052964                  6524660
# calculationPrice                          tops                     tops
# change                                    1.14                    1.485
# changePercent                           0.0229                  0.02859
# close                                    49.78                    51.95
# closeTime                        1522699200487            1522699219276
# companyName       American Airlines Group Inc.     Delta Air Lines Inc.
# delayedPrice                             50.82                    53.31
# delayedPriceTime                 1522777131011            1522777136009
# high                                     51.05                    53.51
# iexAskPrice                              50.92                    53.44
# iexAskSize                                 100                      100
# iexBidPrice                              49.63                    52.08
# iexBidSize                                 100                      100
# iexLastUpdated                   1522778016013            1522778006675
# iexMarketPercent                       0.03279                  0.03395
# iexRealtimePrice                         50.92                   53.435
# iexRealtimeSize                            100                      100
# iexVolume                                54829                   105497
# latestPrice                              50.92                   53.435
# latestSource               IEX real time price      IEX real time price
# latestTime                          1:53:36 PM               1:53:26 PM
# latestUpdate                     1522778016013            1522778006675
# latestVolume                           1672126                  3107423
# low                                      49.57                    52.27
# marketCap                          24092221738              37773915285
# open                                     50.23                    52.49
# openTime                         1522762200849            1522762200162
# peRatio                                  10.39                    10.82
# previousClose                            49.78                    51.95
# primaryExchange           Nasdaq Global Select  New York Stock Exchange
# sector                             Industrials              Industrials
# symbol                                     AAL                      DAL
# week52High                               59.08                    60.79
# week52Low                                40.82                    43.81
# ytdChange                            -0.058771               -0.0791375
#
#                                          LUV
# avgTotalVolume                       4852253
# calculationPrice                        tops
# change                                  1.19
# changePercent                         0.0219
# close                                  54.34
# closeTime                      1522699232185
# companyName       Southwest Airlines Company
# delayedPrice                          55.395
# delayedPriceTime               1522777132859
# high                                   55.54
# iexAskPrice                            55.54
# iexAskSize                               100
# iexBidPrice                            54.02
# iexBidSize                               100
# iexLastUpdated                 1522778023025
# iexMarketPercent                     0.02632
# iexRealtimePrice                       55.53
# iexRealtimeSize                          100
# iexVolume                              56958
# latestPrice                            55.53
# latestSource             IEX real time price
# latestTime                        1:53:43 PM
# latestUpdate                   1522778023025
# latestVolume                         2164058
# low                                    54.46
# marketCap                        32648917531
# open                                   54.94
# openTime                       1522762200409
# peRatio                                15.87
# previousClose                          54.34
# primaryExchange      New York Stock Exchange
# sector                           Industrials
# symbol                                   LUV
# week52High                            66.985
# week52Low                              49.76
# ytdChange                           -0.17851
